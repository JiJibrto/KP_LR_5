# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
response = requests.get('https://sun9-59.userapi.com/impf/c846220/v846220043/af45a/DEPC-4_8MkM.jpg?size=807x454&quality=96&sign=4bc05d6254eb079cc1f39e6c977644c9&type=album')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
